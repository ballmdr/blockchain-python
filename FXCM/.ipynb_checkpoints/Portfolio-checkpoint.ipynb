# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline
import plotly
from plotly import tools
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='ballmdr', api_key='oSgf6vHed7evuaiXDdBb')

import fxcmpy
con = fxcmpy.fxcmpy(config_file = '/Users/ballmdr/blockchain-python/FXCM/fxcm.cfg')

def z(df):
    return (df - df.mean()) / df.std()

def getFig(symbol_focus):
    mean = np.mean(newdf[symbol_focus]['Close_z'])
    sd = np.std(newdf[symbol_focus]['Close_z']) * 3
    tripplesd = sd + mean
    tripplesd2 = mean - sd
    fig = {
        'data': [{
            'type': 'box',
            'y': newdf[symbol_focus]['Close_z'],
            'box': { 'visible': True },
            'line': { 'color': 'black' },
            'meanline': { 'visible': True },
            'fillcolor': '#8dd3c7',
            'opacity': 0.6,
            'x0': symbol_focus
        }],
        'layout': {
            'title': symbol_focus,
            'yaxis': { 'zeroline': False },
            'shapes': [
                # Line Horizontal
                {
                    'type': 'line',
                    'opacity': 0.7,
                    'x0': 0.5,
                    'y0': newdf[symbol_focus].iloc[-1]['Close_z'],
                    'x1': 1,
                    'y1': newdf[symbol_focus].iloc[-1]['Close_z'],
                    'line': {
                        'color': 'rgb(50, 171, 96)',
                        'width': 4,
                        'dash': 'dashdot',
                    },
                },
                {
                    'type': 'line',
                    'opacity': 0.7,
                    'x0': 0.5,
                    'y0': tripplesd,
                    'x1': 1,
                    'y1': tripplesd,
                    'line': {
                        'color': 'red',
                        'width': 4,
                        'dash': 'dashdot',
                    },
                },
                {
                    'type': 'line',
                    'opacity': 0.7,
                    'x0': 0.5,
                    'y0': tripplesd2,
                    'x1': 1,
                    'y1': tripplesd2,
                    'line': {
                        'color': 'red',
                        'width': 4,
                        'dash': 'dashdot',
                    },
                }
            ]
        }
    }
    return fig

# %%
symbols = ['USD/CHF', 'NZD/CHF', 'EUR/JPY', 'GBP/NZD']
pos = dict()
pos[symbols[0]] = 1.00564
pos[symbols[1]] = 0.68550
pos[symbols[2]] = 124.518
pos[symbols[3]] = 1.87615

# %%
df = dict()
for symbol in symbols:
    df[symbol] = con.get_candles(symbol, period='m5', number=5720) #1 Years
    df[symbol]['Close'] = (df[symbol]['bidclose'] + df[symbol]['askclose'])/2
    df[symbol]['Close_z'] = z(df[symbol]['Close'])

# %%
i = 0
for symbol in symbols:
    plt.title(symbol)
    plt.axvline(x=df[symbol].iloc[-1]['Close'], linestyle='--', alpha=0.4)
    plt.axvline(x=pos[symbol], linestyle='--', color='green')
    std = np.std(df[symbol]['Close'])
    mean = np.mean(df[symbol]['Close'])
    plt.axvline(x=mean, color='red', linestyle='--')
    plt.axvline(x=(std*3)+mean, color='red')
    plt.axvline(x=mean-(std*3), color='red')
    sns.distplot(df[symbol]['Close'], hist=False)
    plt.show()
    i += 1

# %%
for symbol in symbols:
    plt.title(symbol)
    plt.axvline(x=df[symbol].iloc[-1]['Close_z'], linestyle='--', alpha=0.4)
    sns.distplot(df[symbol]['Close_z'], hist=False)
    plt.show()

# %%
pairs = [('EUR/JPY', 'NZD/CHF')]
length = len(pairs)
for i in range(length):
    plt.title(pairs[i])
    diff = df[pairs[i][1]]['Close_z'] - df[pairs[i][0]]['Close_z']
    (diff).plot(figsize=(15,7))
    plt.axhline(np.mean(diff), color='red', linestyle='--')
    plt.axhline(y=1, color='red')
    plt.axhline(y=-1, color='red')
    plt.xlabel('Time')
    plt.legend(['Price Ratio', 'Mean'])
    plt.show()
