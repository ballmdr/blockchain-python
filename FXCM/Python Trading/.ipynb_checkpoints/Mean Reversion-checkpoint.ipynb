# %%
import pandas as pd
import numpy as np
from datetime import datetime

import fxcmpy
from apscheduler.schedulers.blocking import BlockingScheduler
import os

os_path = os.getcwd()

def z(df):
    return (df - df.mean()) / df.std()

sched = BlockingScheduler()
lot = 100
tf = 'm1'

@sched.scheduled_job('interval', seconds=60)
def timed_job():
    print('new time job')
    con = fxcmpy.fxcmpy(config_file = 'fxcm.cfg')
    if (len(con.get_open_positions()) > 0):
        check_position(con)
    trading(con)
    
def check_position(con):
    i = 0
    for i in range(len(con.open_pos)):
        print('i = %i' % i)
        trade_id = con.get_open_trade_ids()[i]
        pos = con.get_open_position(trade_id)
        amount = pos.get_amount()
        symbol = pos.get_currency()
        data = con.get_candles(symbol, period=tf, number=100)
        if (pos.get_isBuy()):
            data['Close_z'] = z(data['bidclose'])
            print(data.iloc[-1]['Close_z'])
            if data.iloc[-1]['Close_z'] > -1:
                con.close_trade(trade_id=trade_id, amount=amount)
                print('close %s' % symbol)
            else:
                print('no close')
        else:
            data['Close_z'] = z(data['askclose'])
            print(data.iloc[-1]['Close_z'])
            if data.iloc[-1]['Close_z'] < 1:
                con.close_trade(trade_id=trade_id, amount=amount)
                print('close %s id: %i amount: %i' % (symbol, trade_id, amount))
            else:
                print('no close')
        i += 1
            

    
def trading(con):
    
    symbols = ['EUR/USD', 'USD/JPY', 'GBP/USD', 'USD/CAD', 'USD/CHF', 'AUD/USD', 'NZD/USD', 'EUR/AUD', 'EUR/CAD', 'EUR/CHF', 'EUR/GBP', 'EUR/JPY', 'EUR/NZD', 'GBP/AUD', 'GBP/CAD', 'GBP/CHF', 'GBP/JPY', 'GBP/NZD', 'AUD/CAD', 'AUD/CHF', 'AUD/JPY', 'AUD/NZD', 'NZD/CAD', 'NZD/CHF', 'NZD/JPY', 'CAD/CHF', 'CAD/JPY', 'CHF/JPY']
    df = dict()
    for symbol in symbols:
        df[symbol] = con.get_candles(symbol, period=tf, number=100)
        df[symbol]['bid_Close_z'] = z(df[symbol]['bidclose'])
        df[symbol]['ask_Close_z'] = z(df[symbol]['askclose'])
        if df[symbol].iloc[-1]['ask_Close_z'] < -2:
            print('buy signal')
            if not hasCurrency(con, symbol):
                order = con.create_market_buy_order(symbol, lot)
                if order:
                    print('buy %s success' % symbol)
                else:
                    print('buy %s not success' % symbol)
        elif df[symbol].iloc[-1]['bid_Close_z'] > 2:
            print('sell signal')
            if not hasCurrency(con, symbol):
                order = con.create_market_sell_order(symbol, lot)
                if order:
                    print('sell %s success' % symbol)
                else:
                    print('sell %s not success' % symbol)
    print('---------')

def hasCurrency(con, symbol):
    i = 0
    for i in range(len(con.open_pos)):
        trade_id = con.get_open_trade_ids()[i]
        pos = con.get_open_position(trade_id)
        if symbol == pos.get_currency():
            print('have position')
            return True
    print('%i not have position %s' % (i, symbol))
    return False
    

#@sched.scheduled_job('cron', day_of_week='mon-fri', hour=10)
#def scheduled_job():
#    print('This job is run every weekday at 10am.')

# %%
if __name__ == "__main__":  
    sched.start()
# Out:
# new time job
# i = 0
# -0.5787459336415811
# close GBP/AUD id: 67557168 amount: 1
# i = 1
# -1.1575303853734826
# close EUR/JPY id: 67557114 amount: 100
# buy signal
# 0 not have position EUR/CHF
# buy EUR/CHF success
# ---------
# new time job
# i = 0
# -1.6363093446960137
# no close
# ---------
# new time job
# i = 0
# -1.6743106606404172
# no close
# buy signal
# 0 not have position GBP/USD
# buy GBP/USD success
# buy signal
# 1 not have position GBP/CHF
# buy GBP/CHF success
# ---------
# new time job
# i = 0
# -1.557188892021446
# no close
# i = 1
# -2.241953588467045
# no close
# i = 2
# -2.5560371684011973
# no close
# buy signal
# have position
# buy signal
# have position
# ---------
# new time job
# i = 0
# -1.5223154591982384
# no close
# i = 1
# -2.9709641381554843
# no close
# i = 2
# -2.5955446672326175
# no close
# buy signal
# have position
# buy signal
# have position
# buy signal
# 2 not have position GBP/JPY
# buy GBP/JPY success
# ---------
# new time job
# i = 0
# -1.488917690047972
# no close
# i = 1
# -2.089453222626061
# no close
# i = 2
# -2.767804233446175
# no close
# i = 3
# -2.72321795295573
# no close
# buy signal
# have position
# buy signal
# have position
# buy signal
# have position
# ---------
# new time job
# i = 0
# -1.967232406477425
# no close
# i = 1
# -2.384600782041857
# no close
# i = 2
# -2.796040975451588
# no close
# i = 3
# -2.869002639957599
# no close
# buy signal
# 3 not have position EUR/USD
# buy EUR/USD success
# buy signal
# have position
# buy signal
# have position
# buy signal
# have position
# ---------
# new time job
# i = 0
# -1.908661877423219
# no close
# i = 1
# -2.0925706471896373
# no close
# i = 2
# -2.044949495664192
# no close
# i = 3
# -2.2414382907546675
# no close
# i = 4
# -2.5254122947020283
# no close
# buy signal
# have position
# buy signal
# have position
# buy signal
# have position
# ---------
# new time job
# i = 0
# -2.314445452876538
# no close
# i = 1
# -1.8750214499292674
# no close
# i = 2
# -2.3527344871140023
# no close
# i = 3
# -2.9646354697448274
# no close
# i = 4
# -2.6569322939270448
# no close
# buy signal
# have position
# buy signal
# 4 not have position NZD/USD
# buy NZD/USD success
# buy signal
# have position
# buy signal
# 5 not have position GBP/CAD
# buy GBP/CAD success
# buy signal
# have position
# buy signal
# have position
# buy signal
# 6 not have position NZD/CHF
# buy NZD/CHF success
# buy signal
# 7 not have position NZD/JPY
# buy NZD/JPY success
# ---------
# new time job
# i = 0
# 0.8795619338008641
# close EUR/CHF
# i = 1
# -0.21527187401986705
# close EUR/USD
# i = 2
# 2.126485202889518
# close NZD/JPY
# i = 3
# -0.9684506155510694
# close GBP/CAD
# i = 4
# 0.9912395029977631
# close NZD/USD
# i = 5
# new time job
# i = 0
# -0.24150855723172943
# close GBP/JPY
# i = 1
# -0.4712055169041051
# close GBP/CHF
# i = 2
# -1.3855128032246367
# no close
# i = 3
# new time job
# i = 0
# 0.7367370150436017
# close NZD/CHF
# i = 1
# -0.5581909436724835
# close GBP/USD
# sell signal
# 0 not have position USD/JPY
# sell USD/JPY success
# sell signal
# 0 not have position USD/CHF
# sell USD/CHF success
# sell signal
# 1 not have position AUD/USD
# sell AUD/USD success
# buy signal
# 2 not have position EUR/AUD
# buy EUR/AUD success
# buy signal
# 3 not have position GBP/AUD
# buy GBP/AUD success
# sell signal
# 4 not have position AUD/CHF
# sell AUD/CHF success
# sell signal
# 5 not have position AUD/JPY
# sell AUD/JPY success
# sell signal
# 6 not have position AUD/NZD
# sell AUD/NZD success
# sell signal
# 7 not have position CAD/CHF
# sell CAD/CHF success
# ---------
# new time job
# i = 0
# -1.7802446891197452
# no close
# i = 1
# 1.6446160544186903
# no close
# i = 2
# -1.6884638968760084
# no close
# i = 3
# 1.3216236752927601
# no close
# i = 4
# 3.46295607759193
# no close
# i = 5
# 1.4981672856857131
# no close
# i = 6
# 1.7692587358802074
# no close
# i = 7
# 1.9825668134162497
# no close
# i = 8
# 1.9987900917119221
# no close
# sell signal
# have position
# ---------
# new time job
# i = 0
# -1.528100153639847
# no close
# i = 1
# 1.2891697710603003
# no close
# i = 2
# -1.5052483032978063
# no close
# i = 3
# 1.0160787095664745
# no close
# i = 4
# 2.4640196380576
# no close
# i = 5
# 1.653115051913871
# no close
# i = 6
# 0.5589820696668713
# close CAD/CHF id: 67560939 amount: 100
# i = 7
# 1.609594336158866
# no close
# i = 8
# new time job
# i = 0
# -1.6672779165805849
# no close
# i = 1
# 1.4637961032052624
# no close
# i = 2
# -1.8833183071300823
# no close
# i = 3
# 1.41866772407056
# no close
# i = 4
# 2.6786651886793127
# no close
# i = 5
# 1.6710461845188116
# no close
# i = 6
# 1.7823636338060143
# no close
# i = 7
# 1.7783340127316105
# no close
# sell signal
# have position
# ---------
# new time job
# i = 0
# -1.494686028657648
# no close
# i = 1
# 0.8572817436157518
# close AUD/USD id: 67560932 amount: 100
# i = 2
# -1.4909371010160786
# no close
# i = 3
# 3.719221356634136
# no close
# i = 4
# 1.8333725563240193
# no close
# i = 5
# 1.44370091446496
# no close
# i = 6
# 1.331408300653287
# no close
# i = 7
# new time job
# i = 0
# -1.2760327278188188
# no close
# i = 1
# -1.3357489708159649
# no close
# i = 2
# 2.140440377341873
# no close
# i = 3
# 2.353750770310556
# no close
# i = 4
# 1.5608244886385727
# no close
# i = 5
# 0.980160183136374
# close AUD/CHF id: 67560936 amount: 100
# i = 6
# 1.1460371137374155
# no close
# buy signal
# 5 not have position EUR/USD
# buy EUR/USD success
# sell signal
# have position
# buy signal
# 6 not have position GBP/USD
# buy GBP/USD success
# sell signal
# have position
# ---------
# new time job
# i = 0
# -1.1708784535101235
# no close
# i = 1
# -1.2375531961818547
# no close
# i = 2
# 1.5192943654204454
# no close
# i = 3
# 2.196429591523203
# no close
# i = 4
# 1.7619250457332039
# no close
# i = 5
# -1.4307782333069161
# no close
# i = 6
# -1.2817344575570238
# no close
# i = 7
# 1.137679712812944
# no close
# sell signal
# have position
# ---------
# new time job
# i = 0
# -1.065945054693464
# no close
# i = 1
# -1.2612818383408635
# no close
# i = 2
# 0.9487205350716724
# close USD/JPY id: 67560930 amount: 100
# i = 3
# 0.5908156119208442
# close USD/CHF id: 67560931 amount: 100
# i = 4
# -1.0018634834792608
# no close
# i = 5
# 1.1786725942774323
# no close
# i = 6
# new time job
# i = 0
# -0.8603821748994699
# close GBP/AUD
# i = 1
# -0.9198417181637655
# close EUR/AUD
# i = 2
# -0.9823359044251463
# close EUR/USD
# i = 3
# 0.8118258359353248
# close AUD/JPY id: 67560937 amount: 100
# i = 4
# new time job
# i = 0
# 1.4142099501955603
# no close
# i = 1
# -0.056237866253103355
# close GBP/USD
# ---------
# new time job
# i = 0
# 1.0826703391800123
# no close
# sell signal
# 0 not have position CHF/JPY
# sell CHF/JPY success
# ---------
# new time job
# i = 0
# 1.8000838302323214
# no close
# i = 1
# 1.1041234241873337
# no close
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.8515085504559168
# no close
# i = 1
# 1.1295971405839045
# no close
# buy signal
# 1 not have position NZD/USD
# buy NZD/USD success
# buy signal
# 2 not have position EUR/CHF
# buy EUR/CHF success
# sell signal
# 3 not have position GBP/NZD
# sell GBP/NZD success
# buy signal
# 4 not have position NZD/CAD
# buy NZD/CAD success
# buy signal
# 5 not have position NZD/CHF
# buy NZD/CHF success
# buy signal
# 6 not have position NZD/JPY
# buy NZD/JPY success
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.5259313681857583
# no close
# i = 1
# -2.213189964815922
# no close
# i = 2
# -2.0365563286983877
# no close
# i = 3
# -1.81091726710978
# no close
# i = 4
# 2.0154953684627173
# no close
# i = 5
# 0.7609965286812774
# close AUD/NZD id: 67560938 amount: 100
# i = 6
# -2.10133730968797
# no close
# i = 7
# new time job
# i = 0
# 1.3561368012037918
# no close
# i = 1
# -2.4523803907258452
# no close
# i = 2
# -1.9797211352437925
# no close
# i = 3
# -1.762684720822895
# no close
# i = 4
# 2.1372221282342916
# no close
# i = 5
# -2.105673342475984
# no close
# i = 6
# -1.5882208449976882
# no close
# buy signal
# have position
# buy signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.7080940456612885
# no close
# i = 1
# -2.639063711368292
# no close
# i = 2
# -1.784916729528075
# no close
# i = 3
# -2.0474470590829066
# no close
# i = 4
# 2.60383906020469
# no close
# i = 5
# -2.3057714899428357
# no close
# i = 6
# -1.559517204950543
# no close
# buy signal
# have position
# buy signal
# have position
# buy signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.4902884158402514
# no close
# i = 1
# -2.06927708582078
# no close
# i = 2
# -1.7308862268772514
# no close
# i = 3
# -1.9882401673045018
# no close
# i = 4
# 2.3464024814781466
# no close
# i = 5
# -2.06272750610281
# no close
# i = 6
# -1.5088226652950685
# no close
# buy signal
# have position
# buy signal
# have position
# buy signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.906666184312402
# no close
# i = 1
# -1.9633768737558839
# no close
# i = 2
# -1.68651184970089
# no close
# i = 3
# -1.640747531180049
# no close
# i = 4
# 1.769799760535211
# no close
# i = 5
# -1.7197275078219945
# no close
# i = 6
# -1.350594328347171
# no close
# buy signal
# have position
# ---------
# new time job
# i = 0
# 1.6943022433875723
# no close
# i = 1
# -1.4449844812757582
# no close
# i = 2
# -1.2110144749839287
# no close
# i = 3
# -1.5595327529850411
# no close
# i = 4
# 1.9874864843927298
# no close
# i = 5
# -1.4303838908791204
# no close
# i = 6
# -0.7106361288937567
# close NZD/JPY
# ---------
# new time job
# i = 0
# 0.2806498972800557
# close GBP/NZD id: 67560998 amount: 100
# i = 1
# -0.17570827939801087
# close NZD/CAD
# i = 2
# -1.3192440441776423
# no close
# i = 3
# -0.25395813588629934
# close NZD/CHF
# i = 4
# new time job
# i = 0
# -0.5523446267957797
# close NZD/USD
# i = 1
# -1.2914144007679924
# no close
# i = 2
# new time job
# i = 0
# -1.4935395703563863
# no close
# i = 1
# 1.9054542055870622
# no close
# ---------
# new time job
# i = 0
# -1.4055203572824297
# no close
# i = 1
# 2.07821597661573
# no close
# ---------
# new time job
# i = 0
# -1.4944299057412436
# no close
# i = 1
# 2.161299733208172
# no close
# sell signal
# have position
# ---------
# new time job
# i = 0
# -1.4105900750920364
# no close
# i = 1
# 1.9516049667215603
# no close
# ---------
# new time job
# i = 0
# -1.5011502501659815
# no close
# i = 1
# 1.8255125023783054
# no close
# ---------
# new time job
# i = 0
# -1.4737968649901512
# no close
# i = 1
# 1.9844591898581576
# no close
# sell signal
# 1 not have position CAD/JPY
# sell CAD/JPY success
# ---------
# new time job
# i = 0
# 1.526611891133393
# no close
# i = 1
# -0.9795131337029733
# close EUR/CHF
# i = 2
# 1.6585983477069173
# no close
# ---------
# new time job
# i = 0
# 3.0200133425935376
# no close
# i = 1
# 2.417366722344267
# no close
# sell signal
# 1 not have position USD/JPY
# sell USD/JPY success
# buy signal
# 2 not have position USD/CAD
# buy USD/CAD success
# sell signal
# 3 not have position EUR/JPY
# sell EUR/JPY success
# sell signal
# 4 not have position GBP/JPY
# sell GBP/JPY success
# sell signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 3.3605318297757214
# no close
# i = 1
# 2.770219637224338
# no close
# i = 2
# 2.3470400322599243
# no close
# i = 3
# 2.828852820672607
# no close
# i = 4
# -2.6224767598225687
# no close
# i = 5
# 2.7211305168566766
# no close
# sell signal
# have position
# buy signal
# have position
# buy signal
# 5 not have position EUR/CAD
# buy EUR/CAD success
# sell signal
# have position
# sell signal
# have position
# sell signal
# 6 not have position AUD/JPY
# sell AUD/JPY success
# sell signal
# 7 not have position NZD/JPY
# sell NZD/JPY success
# sell signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.7106935004053776
# no close
# i = 1
# 1.8105363707151252
# no close
# i = 2
# 1.5925791074164573
# no close
# i = 3
# -0.9308340052182854
# close EUR/CAD
# i = 4
# 2.3199390273179836
# no close
# i = 5
# 2.1703454682919054
# no close
# i = 6
# -0.5993875238460905
# close USD/CAD
# i = 7
# 2.3835054097467987
# no close
# i = 8
# new time job
# i = 0
# 2.0682776305095922
# no close
# i = 1
# 1.8747010526887056
# no close
# i = 2
# 2.020529715759206
# no close
# i = 3
# 2.3044657160508706
# no close
# i = 4
# 1.6592699983177612
# no close
# i = 5
# 2.1447797082828544
# no close
# i = 6
# 2.316426709644394
# no close
# sell signal
# have position
# sell signal
# have position
# sell signal
# have position
# sell signal
# have position
# sell signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 2.2649241657860375
# no close
# i = 1
# 1.4367695139988568
# no close
# i = 2
# 1.8746660982065295
# no close
# i = 3
# -1.3078793229635763
# close CHF/JPY id: 67560990 amount: 100
# i = 4
# -0.24212808037205963
# close EUR/JPY id: 67561036 amount: 100
# i = 5
# -2.150075759119784
# close USD/JPY id: 67561033 amount: 100
# i = 6
# new time job
# i = 0
# 2.1253014808398536
# no close
# i = 1
# 1.1051780299010285
# no close
# i = 2
# 1.7542625787570343
# no close
# i = 3
# -1.0400701792695906
# close GBP/JPY id: 67561037 amount: 100
# buy signal
# 2 not have position USD/CAD
# buy USD/CAD success
# sell signal
# 3 not have position AUD/USD
# sell AUD/USD success
# sell signal
# 4 not have position NZD/USD
# sell NZD/USD success
# buy signal
# 5 not have position EUR/AUD
# buy EUR/AUD success
# sell signal
# 6 not have position EUR/CHF
# sell EUR/CHF success
# buy signal
# 7 not have position GBP/AUD
# buy GBP/AUD success
# sell signal
# 8 not have position AUD/CAD
# sell AUD/CAD success
# sell signal
# 9 not have position AUD/CHF
# new time job
# i = 0
# 1.8827120245414726
# no close
# i = 1
# 1.696715001249516
# no close
# i = 2
# 1.503394014860524
# no close
# i = 3
# -1.6065549180517094
# no close
# i = 4
# 1.510043107572174
# no close
# i = 5
# -2.2529276074541986
# no close
# i = 6
# 2.2542301759488526
# no close
# i = 7
# 1.6933338861051916
# no close
# i = 8
# -1.6362921062753786
# no close
# i = 9
# 1.973461258012438
# no close
# buy signal
# have position
# sell signal
# have position
# sell signal
# 9 not have position CAD/CHF
# new time job
# i = 0
# 1.808943760444233
# no close
# i = 1
# 2.5650854055558954
# no close
# i = 2
# 1.467103539947611
# no close
# i = 3
# -1.4273926636455947
# no close
# i = 4
# 0.8077633548631323
# close AUD/CAD id: 67561201 amount: 100
# i = 5
# -3.0240944822760434
# no close
# i = 6
# 1.6705685525912939
# no close
# i = 7
# -1.7564870618356032
# no close
# i = 8
# 1.9436339444616988
# no close
# i = 9
# new time job
# i = 0
# 1.7041446727932965
# no close
# i = 1
# 2.4743297072869255
# no close
# i = 2
# 1.4681445821500512
# no close
# i = 3
# -1.3674425310469498
# no close
# i = 4
# -2.8152279537623364
# no close
# i = 5
# 1.2277420598994377
# no close
# i = 6
# 1.7325828981235325
# no close
# i = 7
# -1.6577168823376092
# no close
# i = 8
# 1.8587068618353704
# no close
# buy signal
# have position
# buy signal
# 8 not have position EUR/CAD
# buy EUR/CAD success
# sell signal
# 9 not have position CAD/CHF
# new time job
# i = 0
# 1.8882819976036544
# no close
# i = 1
# 2.5684013009331723
# no close
# i = 2
# 1.412462854229481
# no close
# i = 3
# -1.503310747931918
# no close
# i = 4
# -2.8309605302827285
# no close
# i = 5
# 2.211629342318253
# no close
# i = 6
# 1.6555758225883683
# no close
# i = 7
# -1.705430560995856
# no close
# i = 8
# -2.5436593720629244
# no close
# i = 9
# 1.9459649943983313
# no close
# buy signal
# have position
# buy signal
# have position
# sell signal
# have position
# sell signal
# 9 not have position CAD/CHF
# new time job
# i = 0
# 1.4105740702664036
# no close
# i = 1
# 2.2153232719037734
# no close
# i = 2
# 1.2311548037021434
# no close
# i = 3
# -1.391659772200359
# no close
# i = 4
# -2.207253416897271
# no close
# i = 5
# 0.5658613174869886
# close EUR/CHF id: 67561199 amount: 100
# i = 6
# 1.3194141858399284
# no close
# i = 7
# -2.656809931060271
# no close
# i = 8
# 1.4310793229650278
# no close
# i = 9
# new time job
# i = 0
# 1.5533132146566675
# no close
# i = 1
# 2.5332797893985846
# no close
# i = 2
# 1.3674990356511882
# no close
# i = 3
# -1.3455041801897167
# no close
# i = 4
# -2.2174170979962167
# no close
# i = 5
# 1.291505046083436
# no close
# i = 6
# -1.5872862909456653
# no close
# i = 7
# -2.6600644179864052
# no close
# i = 8
# 1.4602730658552903
# no close
# buy signal
# have position
# buy signal
# have position
# sell signal
# 8 not have position CAD/CHF
# sell CAD/CHF success
# buy signal
# 9 not have position CHF/JPY
# new time job
# i = 0
# 0.23542495627356852
# close AUD/JPY id: 67561046 amount: 100
# i = 1
# 1.045072761171675
# no close
# i = 2
# -0.7803114662757987
# close GBP/AUD
# i = 3
# -1.611031340837175
# no close
# i = 4
# 0.6813948584814112
# close NZD/USD id: 67561196 amount: 100
# i = 5
# -0.9221441219792669
# close EUR/AUD
# i = 6
# 0.6349088690522495
# close AUD/USD id: 67561195 amount: 100
# i = 7
# new time job
# i = 0
# 0.7706405713618971
# close CAD/JPY id: 67561031 amount: 100
# i = 1
# 0.07535474988986227
# close NZD/JPY id: 67561047 amount: 100
# i = 2
# 2.0428969286430543
# no close
# i = 3
# new time job
# i = 0
# -1.5931552140665481
# no close
# i = 1
# 2.0260864757854247
# no close
# i = 2
# -1.9828893632625193
# no close
# sell signal
# 2 not have position USD/CHF
# sell USD/CHF success
# sell signal
# have position
# ---------
# new time job
# i = 0
# 2.234269839769017
# no close
# i = 1
# -1.6079799881328056
# no close
# i = 2
# 2.142148714823899
# no close
# i = 3
# -2.1328268081756065
# no close
# sell signal
# have position
# buy signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 2.3118235563067198
# no close
# i = 1
# -1.621450329995722
# no close
# i = 2
# 2.0753072493279787
# no close
# i = 3
# -2.2158227262293098
# no close
# sell signal
# have position
# buy signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 1.9919340583887164
# no close
# i = 1
# -1.6076645367125553
# no close
# i = 2
# 2.055873729261786
# no close
# i = 3
# -2.092402976350373
# no close
# buy signal
# have position
# sell signal
# have position
# ---------
# new time job
# i = 0
# 2.0673245707746757
# no close
# i = 1
# -1.413436351723359
# no close
# i = 2
# 1.9507160094802793
# no close
# i = 3
# -1.9531661925150585
# no close
# ---------
# new time job
# i = 0
# 0.4898876416277507
# close USD/CHF id: 67561221 amount: 100
# i = 1
# -1.352195391130524
# no close
# i = 2
# -1.6329651832909806
# no close
# i = 3
# new time job
# i = 0
# -1.5507591209197205
# no close
# i = 1
# 1.6090132846927845
# no close
# i = 2
# -1.593011952205761
# no close
# buy signal
# 2 not have position USD/JPY
# buy USD/JPY success
# buy signal
# 3 not have position EUR/NZD
# buy EUR/NZD success
# buy signal
# 4 not have position CHF/JPY
# buy CHF/JPY success
# ---------
# new time job
# i = 0
# -1.3820086368324698
# no close
# i = 1
# 1.3264445163357605
# no close
# i = 2
# -1.418069079533405
# no close
# i = 3
# -1.6531601253688712
# no close
# i = 4
# -1.5772240519528833
# no close
# i = 5
# -1.4363485040523372
# no close
# ---------
# new time job
# i = 0
# -1.758992109894163
# no close
# i = 1
# 1.3501402479763174
# no close
# i = 2
# -0.9289829510252597
# close CHF/JPY
# i = 3
# -1.8978771897084712
# no close
# i = 4
# -1.634007010379315
# no close
# i = 5
# new time job
# new time job
# i = 0
# -2.871673697815815
# no close
# i = 1
# -0.046040858803359924
# close CAD/CHF id: 67561215 amount: 100
# i = 2
# -1.5349649587992413
# no close
# i = 3
# 0.9663452313982069
# close EUR/NZD
# i = 4
# new time job
# i = 0
# -2.723303746668353
# no close
# i = 1
# -1.458051154955784
# no close
# i = 2
# 0.7574015120761041
# close USD/JPY
# buy signal
# have position
# buy signal
# 1 not have position USD/CHF
# buy USD/CHF success
# buy signal
# 2 not have position AUD/CAD
# buy AUD/CAD success
# sell signal
# 3 not have position CAD/JPY
# sell CAD/JPY success
# sell signal
# 4 not have position CHF/JPY
# sell CHF/JPY success
# ---------
# new time job
# i = 0
# -2.4597219348480577
# no close
# i = 1
# 2.3003948655683994
# no close
# i = 2
# -2.7127714837810997
# no close
# i = 3
# -2.480205728553381
# no close
# i = 4
# -1.3852384777181492
# no close
# i = 5
# 3.0805904599232785
# no close
# buy signal
# have position
# buy signal
# have position
# sell signal
# 5 not have position EUR/AUD
# sell EUR/AUD success
# buy signal
# 6 not have position EUR/CHF
# buy EUR/CHF success
# sell signal
# 7 not have position EUR/JPY
# sell EUR/JPY success
# sell signal
# 8 not have position GBP/AUD
# sell GBP/AUD success
# buy signal
# have position
# buy signal
# 9 not have position AUD/CHF
# new time job
# i = 0
# -2.040759156513757
# no close
# i = 1
# 1.6991762832264725
# no close
# i = 2
# -2.5174055010303484
# no close
# i = 3
# 1.7986899497856272
# no close
# i = 4
# 1.8359580046844926
# no close
# i = 5
# -2.3652557035998476
# no close
# i = 6
# -1.7876561615344755
# no close
# i = 7
# 1.8015501724890122
# no close
# i = 8
# -0.8257469649013558
# close EUR/CAD
# i = 9
# 2.7096623926099057
# no close
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-cebf43dbc3dd> in <module>
#       1 if __name__ == "__main__":
# ----> 2     sched.start()
#
# /anaconda2/envs/fxcm/lib/python3.7/site-packages/apscheduler/schedulers/blocking.py in start(self, *args, **kwargs)
#      17         self._event = Event()
#      18         super(BlockingScheduler, self).start(*args, **kwargs)
# ---> 19         self._main_loop()
#      20
#      21     def shutdown(self, wait=True):
#
# /anaconda2/envs/fxcm/lib/python3.7/site-packages/apscheduler/schedulers/blocking.py in _main_loop(self)
#      26         wait_seconds = TIMEOUT_MAX
#      27         while self.state != STATE_STOPPED:
# ---> 28             self._event.wait(wait_seconds)
#      29             self._event.clear()
#      30             wait_seconds = self._process_jobs()
#
# /anaconda2/envs/fxcm/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /anaconda2/envs/fxcm/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
